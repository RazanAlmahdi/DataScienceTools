# %%
import yfinance as yf

# Define the stock symbol
symbol = 'TSLA'

# Download the stock data
tesla_data = yf.download(symbol)

# Reset index
tesla_data.reset_index(inplace=True)

# Save dataframe to a file (e.g., CSV)
tesla_data.to_csv('TSLA.csv', index=False)

# Display the first five rows
print(tesla_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
import pandas as pd

# Assuming you have the tesla_revenue dataframe already loaded or created

# Display the last five rows
print(tesla_data.tail())
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 3424 2024-02-06  177.210007  186.490005  177.110001  185.100006  185.100006
# 3425 2024-02-07  188.179993  189.789993  182.679993  187.580002  187.580002
# 3426 2024-02-08  189.000000  191.619995  185.580002  189.559998  189.559998
# 3427 2024-02-09  190.179993  194.119995  189.479996  193.570007  193.570007
# 3428 2024-02-12  192.110001  194.729996  187.279999  188.130005  188.130005
#
#          Volume
# 3424  122676000
# 3425  111535200
# 3426   83034000
# 3427   84327600
# 3428   95260000

# %%
import yfinance as yf

# Define the stock symbol
symbol = 'GME'

# Download the stock data
gme_data = yf.download(symbol)

# Reset index
gme_data.reset_index(inplace=True)

# Save dataframe to a file (e.g., CSV)
gme_data.to_csv('gme_data.csv', index=False)

# Display the first five rows
print(gme_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date     Open     High      Low    Close  Adj Close    Volume
# 0 2002-02-13  2.40625  2.51500  2.38125  2.51250   1.691666  76216000
# 1 2002-02-14  2.54375  2.54875  2.48125  2.50000   1.683250  11021600
# 2 2002-02-15  2.50000  2.50625  2.46250  2.48750   1.674834   8389600
# 3 2002-02-19  2.47500  2.47500  2.34375  2.38750   1.607504   7410400
# 4 2002-02-20  2.40000  2.46875  2.38125  2.46875   1.662210   6892800

# %%
import pandas as pd

# Assuming you have the tesla_revenue dataframe already loaded or created

# Display the last five rows
print(gme_data.tail())
# Out:
#            Date   Open   High    Low  Close  Adj Close   Volume
# 5532 2024-02-06  13.60  14.30  13.43  14.10      14.10  3047800
# 5533 2024-02-07  14.12  14.30  13.78  14.07      14.07  1947800
# 5534 2024-02-08  14.01  14.44  13.89  14.35      14.35  1838300
# 5535 2024-02-09  14.37  15.23  14.30  14.66      14.66  3571600
# 5536 2024-02-12  14.58  15.22  14.53  14.73      14.73  2747500

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'])
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.title(title)
    plt.grid(True)
    plt.show()

# Define the stock symbol
symbol = 'TSLA'

# Download the stock data
tesla_data = yf.download(symbol)

# Reset index
tesla_data.reset_index(inplace=True)

# Call the make_graph function
make_graph(tesla_data, 'Tesla Stock Data')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'])
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.title(title)
    plt.grid(True)
    plt.show()

# Define the stock symbol
symbol = 'GME'

# Download the stock data
gme_data = yf.download(symbol)

# Reset index
gme_data.reset_index(inplace=True)

# Call the make_graph function
make_graph(gme_data, 'GME Stock Data')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ##Author
# Razan Almahdi
